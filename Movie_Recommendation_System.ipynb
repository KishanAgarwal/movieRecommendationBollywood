# %% [markdown]
# <a href="https://colab.research.google.com/github/KishanAgarwal/movieRecommendationBollywood/blob/main/Movie_Recommendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Dependencies

# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Data Collection and preprocessing

# %%
#loading the data from csv file to a pandas dataframe
movies_data = pd.read_csv('/content/All_Bollywood_movies_since_1990.csv')

# %%
movies_data.head()
# Out:
#    index      title                       genres  \
# 0      0      Jawan      Action, Drama, Thriller
# 1      1   Gaslight     Crime, Mystery, Thriller
# 2      2    Tiger 3  Action, Adventure, Thriller
# 3      3  Am I Next                        Crime
# 4      4   Shehzada        Action, Comedy, Drama
#
#                                           story_line  \
# 0                                                NaN
# 1  Misha, who returns to her royal family estate ...
# 2                                                NaN
# 3  A sudden shock grabs the family of 14-year old...
# 4  Bantu is hated by his father Valmiki since he ...
#
#                                                 cast         director
# 0  Shah Rukh Khan,Nayanthara,Vijay Sethupathi,Dee...            Atlee
# 1  Sara Ali Khan,Vikrant Massey,Chitrangda Singh,...  Pavan Kirpalani
# 2            Salman Khan,Katrina Kaif,Shah Rukh Khan   Maneesh Sharma
# 3    Anushka Sen,Neelu Dogra,Tariq Khan,Ahmer Haider      Rahat Kazmi
# 4  Kartik Aaryan,Kriti Sanon,Paresh Rawal,Manisha...     Rohit Dhawan

# %%
#number of rows and columns in df
movies_data.shape
# Out:
# (7996, 6)

# %%
#selecting the relevant features for recommendation
selected_features =['genres', 'story_line', 'cast', 'director']

# %%
#replacing the null values with null string
for feature in selected_features:
  movies_data[feature] = movies_data[feature].fillna('')

# %%
movies_data.head()
# Out:
#    index      title                       genres  \
# 0      0      Jawan      Action, Drama, Thriller
# 1      1   Gaslight     Crime, Mystery, Thriller
# 2      2    Tiger 3  Action, Adventure, Thriller
# 3      3  Am I Next                        Crime
# 4      4   Shehzada        Action, Comedy, Drama
#
#                                           story_line  \
# 0
# 1  Misha, who returns to her royal family estate ...
# 2
# 3  A sudden shock grabs the family of 14-year old...
# 4  Bantu is hated by his father Valmiki since he ...
#
#                                                 cast         director
# 0  Shah Rukh Khan,Nayanthara,Vijay Sethupathi,Dee...            Atlee
# 1  Sara Ali Khan,Vikrant Massey,Chitrangda Singh,...  Pavan Kirpalani
# 2            Salman Khan,Katrina Kaif,Shah Rukh Khan   Maneesh Sharma
# 3    Anushka Sen,Neelu Dogra,Tariq Khan,Ahmer Haider      Rahat Kazmi
# 4  Kartik Aaryan,Kriti Sanon,Paresh Rawal,Manisha...     Rohit Dhawan

# %%
#combining all the 5 selected feature
combined_features = movies_data['genres'] + ' '+movies_data['story_line'] + ' '+movies_data['cast'] + ' '+movies_data['director'] 
print(combined_features)
# Out:
# 0       Action, Drama, Thriller  Shah Rukh Khan,Nayant...
# 1       Crime, Mystery, Thriller Misha, who returns to...
# 2       Action, Adventure, Thriller  Salman Khan,Katri...
# 3       Crime A sudden shock grabs the family of 14-ye...
# 4       Action, Comedy, Drama Bantu is hated by his fa...
#                               ...
# 7991    Horror, Mystery Suraj and Nisha loved each oth...
# 7992    Drama, Mystery Imran is a professional freelan...
# 7993    Mystery, Thriller Ravi gets a call from Father...
# 7994    Action, Drama, Family Anita lives an abusive l...
# 7995    Action, Crime, Drama A poor, young man teams u...
# Length: 7996, dtype: object

# %%
#converting the text data to feature vectors
vectorizer = TfidfVectorizer()

# %%
feature_vectors = vectorizer.fit_transform(combined_features)

# %%
print(feature_vectors)
# Out:
#   (0, 1794)	0.4286282438206996
#   (0, 13955)	0.32990020748288296
#   (0, 5108)	0.3058361126229332
#   (0, 17658)	0.44296558104590017
#   (0, 21160)	0.22520349801151737
#   (0, 13267)	0.4286282438206996
#   (0, 10450)	0.14399395675175533
#   (0, 16739)	0.2874281516547873
#   (0, 17725)	0.1997452580565963
#   (0, 20072)	0.13809190083439452
#   (0, 5915)	0.08303565821076478
#   (0, 481)	0.11848627489077504
#   (1, 10620)	0.2512920351280763
#   (1, 14338)	0.225310633597143
#   (1, 5308)	0.15300056019734906
#   (1, 15512)	0.14001986211843417
#   (1, 18419)	0.09528682209405354
#   (1, 4019)	0.2356281626413825
#   (1, 12036)	0.23003748456195966
#   (1, 21205)	0.20194049702440597
#   (1, 888)	0.12205643088697028
#   (1, 17235)	0.20517125446023993
#   (1, 12508)	0.18689611701534983
#   (1, 8446)	0.11789583159693617
#   (1, 6943)	0.13974969442627477
#   :	:
#   (7995, 7609)	0.2029766630526198
#   (7995, 235)	0.19823391997702158
#   (7995, 2739)	0.1993585741427287
#   (7995, 7357)	0.19407648191704444
#   (7995, 4574)	0.1960911999203843
#   (7995, 7106)	0.21510068428596188
#   (7995, 19388)	0.2394093901403049
#   (7995, 13847)	0.14263522524698158
#   (7995, 14076)	0.17403000919469602
#   (7995, 14283)	0.18473980407394078
#   (7995, 14740)	0.17322989657785942
#   (7995, 21647)	0.08920074371111886
#   (7995, 20794)	0.14221219148213385
#   (7995, 549)	0.16345868279976658
#   (7995, 11780)	0.1246648922915922
#   (7995, 21846)	0.13338520142763285
#   (7995, 8499)	0.0831592090446811
#   (7995, 3419)	0.10518390814896347
#   (7995, 13693)	0.13358222082878457
#   (7995, 19992)	0.06096392335006737
#   (7995, 20178)	0.06572915254902305
#   (7995, 4707)	0.10483502705942419
#   (7995, 10450)	0.09747395720501101
#   (7995, 5915)	0.056209401960387075
#   (7995, 481)	0.08020701943759725

# %% [markdown]
# Cosine Similarity

# %%
#getting similarity score using cosine similarity
similarity = cosine_similarity(feature_vectors)

# %%
print(similarity)
# Out:
# [[1.         0.02449026 0.2257105  ... 0.04626206 0.01133792 0.02820648]
#  [0.02449026 1.         0.0426565  ... 0.08948239 0.09419484 0.03040572]
#  [0.2257105  0.0426565  1.         ... 0.05298003 0.00870776 0.04303118]
#  ...
#  [0.04626206 0.08948239 0.05298003 ... 1.         0.04105136 0.02318535]
#  [0.01133792 0.09419484 0.00870776 ... 0.04105136 1.         0.03154954]
#  [0.02820648 0.03040572 0.04303118 ... 0.02318535 0.03154954 1.        ]]

# %%
similarity.shape
# Out:
# (7996, 7996)

# %%
#getting movie name from user
movie_name = input('Enter your favourite movie name:- ')
# Out:
# Enter your favourite movie name:- pathaan

# %%
#creating a list with all movie name given in datasheet
list_of_all_titles = movies_data['title'].tolist()
print(list_of_all_titles)
# Out:
# ['Jawan', 'Gaslight', 'Tiger 3', 'Am I Next', 'Shehzada', 'Gumraah', 'Animal', 'Yodha', 'Lohardaga', 'Bade Miyan Chote Miyan', 'Gandhi Godse Ek Yudh', 'Gadar 2', 'Rocky Aur Rani Ki Prem Kahani', 'The Archies', 'Ganapath', 'Adipurush', 'Dream Girl 2', 'Operation Fryday', 'SamBahadur', 'Ek Tha Hero', 'Merry Christmas', 'Fukrey 3', 'Untitled Soorarai Pottru remake', 'Mrs Undercover', 'Haddi', 'InCar', 'Joram', 'A Winter Tale at Shimla', 'Tariq', 'Bull', 'Indian Gurjar', 'Aankh Micholi', 'Bawaal', 'Swatantra Veer Savarkar', 'Maidaan', 'Zindagi Shatranj Hai', 'Bicycle Days', 'The Devotion of Suspect X', 'Pippa', 'Satyaprem Ki Katha', 'Chhipkali', 'The Journey of Donkers', 'Penthouse', 'The Era of 1990', 'Karma Strikes', 'Bad Boy', 'The Check Post', 'Main Atal Hoon', 'Shaktimaan', 'All India Rank', 'Main Raj Kapoor Ho Gaya', 'Sleeping with The Enemy', 'The Y', 'Angoor', 'Who Am I', 'Kanwar', 'Hume Toh Loot Liya', 'Lakadbaggha', 'Metro... In dhino', 'Tipppsy', 'Welcome to Kashmir', 'Sri', 'Ho Ja Mukt', 'Emergency', 'Aazam', 'Ab Dilli Dur Nahin', 'The Vaccine War', 'Wrong Way', 'Manduka', 'Secrets of Love', '8 Years', 'Timir', 'Junglemahal: The Awakening', 'Firrkie', 'Khela Hobe', 'Yeh Shaadi Nahi Ho Sakti', 'Kaushaljis VS Kaushal', 'Yaariyan 2', 'Ticket ek Sangharsh', 'Oye Jassi Oye', 'The Last Coffee', 'Sachin: The Ultimate Winner', 'Victor', 'Angithee 2', 'Dr. Hedgewar', 'Woh Ladki Hai Kahaan', 'Kakuda', 'The Last Coffee', 'Mrs. Falani', 'Sector Balakot', 'Pedigree', 'Rosh', 'Hum Banjarey: The Reluctant Crime', 'LaVaste', 'Ittar', 'Kaal Trighori', 'Aatmapamphlet', 'Helen', '3rd October', 'Chatrapathi', 'Moha', 'Rat on a Highway', 'Music School', 'Anubhooti...At Metaphysical World', 'The Underbug', 'Char Cup Chai', 'Deendayal Ek Yug Purush', 'Ghaznavi', 'Pyar Mei Qurban', 'Death Tale', 'The 30 Days', 'Raashifal', 'Dushu', 'Nasha Jurm Aur Gangsters', 'RED', 'One Way', 'India Fashion Factory', 'Shukrdosh', 'Ek Kori Prem Katha', 'Bhalessa', 'One Last Time', 'Love in a Taxi', 'Fatal: Chapter 1', 'Walk', 'Bluff', 'Raktneeti', 'Salam-e-Madrasa', "Mom's Coming", 'The Film House', 'UnWoman', 'Bombay', 'Love in A Taxi', 'Palak', 'Behind Veils', 'Kayo Kayo Colour? (Which Colour?)', 'Devanand Dheere Dheere', 'Labour Pain - an unending saga', 'Bandit Shakuntala', 'Pyar Ki Policy', 'Paramahans Lakshminath Gosain', 'Jaaiye Aap Kahan Jaayenge', 'The Dark Face', 'Tantra', 'Mask', 'Navras Katha Collage', 'Devbhoomi', 'Alien Frank', 'Elham', 'Hide & Seek', 'The Curse of the Trishul', 'Kaala Barbarian Chapter 1', 'Agwah', 'Target India', 'Kaun Ho Tum', 'Hanere Panne - The Dark Chapter', 'Paraagan', 'Bhagwa', 'Shaque- The Doubt!', 'Eternite', 'Kritn Babu', 'Aham Brahmasmi Hindi', 'Twinkle', 'Nepotism', 'Dhoort', 'Weekdays & Weekends', 'Bera: Ek Aghori', 'Roached', 'The Unbelievable Show: Made History', 'Vo Ladki', 'His popular tweet', 'Age 29', 'Anurag Kashyap', 'Beech Mein Mat Bol', 'Meri Awaaz Suno', 'Kaanchi (A Terrible Story)', 'Mystery of Journey', 'No Tears Left to Cry', 'Camera Ka Kamaal', 'Pandit Asraf', 'Rudra the Power', 'Zindagi Tere Naan', 'New York to Haridwar', 'Teri Meri Kahaani', 'The Invisible Hubby', 'Jadhav Pandit', 'Born Fire: Ek Agg', 'The Mystic Father', 'Gandhi vs Aazaad', 'Ruhani Ishq', 'Sorry Mother', 'Lazarus Herofication', 'Ek Naya Sawera', 'See You in Hell', 'Soo Jaa Mukesh', 'Marne Ke Dar Se Mere Dil', 'Aaj Mere Pyaar Ki Shadi Hai', 'Naari Ek Prerna', 'The Face of the Faceless by Tri Light Creation', 'Jhansa the Lollypop', 'Smart Killer', 'Secret Eyes', 'Zwigato', 'Doragon bôru sûpâ: Sûpâ hîrô', 'Bhediya', 'Drishyam 2', 'Freddy', 'Lost', 'An Action Hero', 'Vikram Vedha', 'Gangubai Kathiawadi', 'Brahmastra Part One: Shiva', 'Monica O My Darling', 'Cuttputlli', 'Cirkus', 'Qala', 'Chup', 'Laal Singh Chaddha', 'Uunchai', 'Raksha Bandhan', 'Vadh', 'Govinda Naam Mera', 'Doctor G', 'Runway 34', 'Dhokha: Round D Corner', 'Salaam Venky', 'The Kashmir Files', 'Mili', 'Darlings', 'A Thursday', 'Goodbye', 'Dobaaraa', 'Ram Setu', 'Badha ...

# %%
#finding the close match for the movie name given by the user
find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
print(find_close_match)
# Out:
# ['Apaharan', 'Utthaan', 'Santaan']

# %%
close_match = find_close_match[0]
print(close_match)
# Out:
# Monica O My Darling

# %%
#finding index of the movie with title
index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]
print(index_of_the_movie)
# Out:
# 211

# %%
#getting a list of similar movies
similarity_score = list(enumerate(similarity[index_of_the_movie]))

# %%
len(similarity_score)
# Out:
# 7996

# %%
#sorting the movies based on their similarity score
sorted_similar_movies = sorted(similarity_score, key= lambda x:x[1], reverse = True)
print(sorted_similar_movies)
# Out:
# [(211, 1.0000000000000002), (4191, 0.15824746334708684), (2795, 0.15281548602874123), (191, 0.14437637685690446), (1809, 0.13866367495244966), (7907, 0.13783185630022704), (271, 0.12683562334992954), (1790, 0.1250545273518762), (3327, 0.11770692163904137), (3470, 0.11582211631941759), (2200, 0.11557594965762621), (3140, 0.11353412342354897), (2309, 0.11134803707382188), (2176, 0.10814095720025081), (1844, 0.10658471922139044), (1015, 0.10635307074748339), (3019, 0.10559906229975212), (322, 0.10313760681168226), (4259, 0.10268031376271124), (1696, 0.10251750419251253), (1119, 0.10023536135141385), (1272, 0.09954249675097691), (3656, 0.09558015291400467), (7339, 0.0941457949084522), (6281, 0.09364381786648088), (208, 0.09306729848130732), (2202, 0.0929505789500992), (6721, 0.09227132683047713), (3676, 0.09219861934840072), (3381, 0.09166567117860613), (7702, 0.09156124061013467), (1081, 0.09124806392344753), (6212, 0.09046434625402883), (3915, 0.0903275863172489), (4701, 0.0900952937446515), (3239, 0.0899690626287356), (3869, 0.08850885182431076), (544, 0.08830397640964348), (7809, 0.08799740744368016), (447, 0.08770867809691892), (2748, 0.08719669849135053), (5585, 0.08690500121445206), (3770, 0.08657196704003606), (2157, 0.08622290201212439), (2150, 0.08584435732458995), (637, 0.08582438586544555), (671, 0.08582438586544555), (1088, 0.08582438586544555), (1849, 0.08582438586544555), (3994, 0.0857346559444837), (1471, 0.08564166496746135), (3486, 0.08549501421505827), (2553, 0.08542403779192925), (7166, 0.08501886711233865), (6333, 0.08485417941793351), (5519, 0.08470958554813869), (4423, 0.08467582938186138), (3867, 0.08459795254089425), (6224, 0.08387282079876414), (716, 0.08371965513759654), (3886, 0.08331214528548694), (5077, 0.08274000110623712), (5193, 0.08246453143263917), (654, 0.08212706322810369), (6940, 0.08163628446188118), (1755, 0.08116421805532281), (2780, 0.08115314620456228), (3528, 0.08108642240528129), (3244, 0.08106647871430024), (1818, 0.08104070365140852), (1530, 0.08098927844243327), (3226, 0.0809396422058308), (2547, 0.08064320916290875), (7190, 0.08063955948831514), (232, 0.07985896062185852), (1111, 0.0796572334639035), (7542, 0.07954636022665669), (852, 0.07924294985520483), (2781, 0.07885625445299087), (5366, 0.07878136329597017), (2496, 0.07859815272705682), (2046, 0.07849837521611723), (2774, 0.07838752607890186), (6823, 0.07834958922263716), (269, 0.07830194435662448), (23, 0.07800807784844548), (4703, 0.0778542897754634), (3315, 0.07783940532492314), (5056, 0.07771003625788628), (1153, 0.07748169507975802), (2545, 0.07695950293561321), (777, 0.07683893258723717), (2548, 0.07662346697103557), (3499, 0.07648685166094818), (731, 0.07644984066413266), (1136, 0.07639535804122524), (6428, 0.0760282625534279), (4469, 0.07555541244161253), (2769, 0.07547965308018156), (3015, 0.07516087920351468), (2756, 0.07514101118969853), (4020, 0.0749883512235121), (1793, 0.0749803038092157), (2034, 0.07491046821061574), (3854, 0.07482220032364452), (4542, 0.0746920383460712), (4375, 0.07466201699027361), (3487, 0.0742774272928476), (7178, 0.07397623709351223), (6651, 0.0738254742848775), (3267, 0.07367539812660212), (2861, 0.0736735849260257), (5941, 0.07361922815750913), (288, 0.07355810238087908), (1702, 0.07349393929628614), (2357, 0.07349393929628614), (5234, 0.07349393929628614), (5430, 0.07349393929628614), (5458, 0.07349393929628614), (6188, 0.07349393929628614), (6735, 0.07349393929628614), (7661, 0.07349393929628614), (2475, 0.07337762439864508), (7663, 0.07334004621903527), (2476, 0.07311351395220694), (6947, 0.0730899402527762), (6222, 0.07308288736287485), (6723, 0.07299954397095305), (5732, 0.07296653063932788), (2628, 0.07281822666727408), (4997, 0.07267535928348695), (6614, 0.07245482835056798), (3010, 0.07244353687101945), (7634, 0.07185723385933719), (2197, 0.071692913129322), (2185, 0.07161849208413512), (6779, 0.07145528178237621), (4317, 0.07131858212161234), (3137, 0.0712080162716211), (2491, 0. ...

# %%
#print the name of similar movies based on the index
print('Movies suggested for you : \n')
i = 1
for movie in sorted_similar_movies:
  index = movie[0]
  title_from_index = movies_data[movies_data.index == index]['title'].values[0]
  if(i<10):
    print(i,'\b.', title_from_index)
    i+=1
# Out:
# Movies suggested for you :
#
# . Monica O My Darling
# . Aamir
# . Loev
# . Ek Naya Sawera
# . Mard Ko Dard Nahin Hota
# . Bombay War
# . Forensic
# . Andhadhun
# . Shorts

# %% [markdown]
# Movie Recommendation System

# %%
movie_name = input('Enter your favourite movie name:- ')
list_of_all_titles = movies_data['title'].tolist()
try:
  find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
  close_match = find_close_match[0]
except:
  print('Movie not present in Dataset')
  exit()
index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]
similarity_score = list(enumerate(similarity[index_of_the_movie]))
sorted_similar_movies = sorted(similarity_score, key= lambda x:x[1], reverse = True)
print('Movies suggested for you : \n')
i = 1
for movie in sorted_similar_movies:
  index = movie[0]
  title_from_index = movies_data[movies_data.index == index]['title'].values[0]
  if(i<20):
    print(i,'\b.', title_from_index)
    i+=1
# Out:
# Enter your favourite movie name:- yeh jawani hai deewani
# Movies suggested for you :
#
# . Yeh Jawaani Hai Deewani
# . Mere Naina Sawan Bhadon
# . Khiladi 1080
# . Brahmastra Part One: Shiva
# . Shimla Mirchi
# . Chakravyuh
# . Kal Ho Naa Ho
# . Itihaas
# . Roy
# . Tamasha
# . Pyar Ka Karz
# . Aashiq Banaya Aapne: Love Takes Over
# . Saawariya
# . Beautiful
# . Helicopter Eela
# . Bachna Ae Haseeno
# . Rockstar
# . Wake Up Sid
# . Kuch Kuch Hota Hai
